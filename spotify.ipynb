# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Get the key and secret key from Spotify

client_credentials_manager = SpotifyClientCredentials(client_id = "", 
                                                      client_secret = "")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
sp.user_playlists('spotify')
# Out:
# {'href': 'https://api.spotify.com/v1/users/spotify/playlists?offset=0&limit=50',
#  'items': [{'collaborative': False,
#    'description': 'Olivia Rodrigo is on top of the Hottest 50!',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcBWIGoYBM5M'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M',
#    'id': '37i9dQZF1DXcBWIGoYBM5M',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f00000003afec821c60fe0194f700e775',
#      'width': None}],
#    'name': "Today's Top Hits ",
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTY4ODA5NzYwMCwwMDAwMDAwMGFiN2ExNzU1M2YxMGZlMTJhYjMyMGVlNzIzZmUzYWMy',
# ...

# %%
playlist = "https://open.spotify.com/playlist/37i9dQZF1DX4W3aJJYCDfV"

# %%
playlist_URI = playlist.split('/')[-1]
playlist_URI
# Out:
# '37i9dQZF1DX4W3aJJYCDfV'

# %% [markdown]
# <strong>JSON Object<strong/>

# %%
result = sp.playlist_tracks(playlist_URI)
result
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4W3aJJYCDfV/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-06-30T10:20:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#        'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#        'id': '1McMsnEElThX1knmY4oliG',
#        'name': 'Olivia Rodrigo',
#        'type': 'artist',
#        'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
# ...

# %%
result.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
result_item = result['items']
result_item
# Out:
# [{'added_at': '2023-06-30T10:20:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#       'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#       'id': '1McMsnEElThX1knmY4oliG',
#       'name': 'Olivia Rodrigo',
#       'type': 'artist',
#       'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
# ...

# %%
len(result_item)
# Out:
# 100

# %%
"""
Items to scrape
--tracks
--"""
# Out:
# '\nItems to scrape\n--tracks\n--'

# %%
first_page = result_item[0]
first_page
# Out:
# {'added_at': '2023-06-30T10:20:05Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#      'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#      'id': '1McMsnEElThX1knmY4oliG',
#      'name': 'Olivia Rodrigo',
#      'type': 'artist',
#      'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
# ...

# %%
album_ID = first_page['track']['album']['id']
album_ID
# Out:
# '5kqfR7EuGbyp8x27Pr1kY9'

# %%
album_name = first_page['track']['album']['name']
album_name
# Out:
# 'vampire'

# %%
song_time = first_page['added_at']
song_time
# Out:
# '2023-06-30T10:20:05Z'

# %%
artist_id = first_page['track']['id']
artist_id
# Out:
# '3k79jB4aGmMDUQzEwa46Rz'

# %%
artist_name = first_page['track']['artists'][0]['name']
artist_name
# Out:
# 'Olivia Rodrigo'

# %%
song_name = first_page['track']['name']
song_name
# Out:
# 'vampire'

# %%
release_date = first_page['track']['album']['release_date']
release_date
# Out:
# '2023-06-30'

# %%
total_tracks = first_page['track']['album']['total_tracks']
total_tracks
# Out:
# 1

# %%
url = first_page['track']['album']['artists'][0]['external_urls']['spotify']
url
# Out:
# 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'

# %%
duration = first_page['track']['duration_ms']
duration
# Out:
# 219724

# %%
popu = first_page['track']['popularity']
popu
# Out:
# 85

# %%
exp = first_page['track']['explicit']
exp
# Out:
# True

# %%
uri = first_page['track']['uri']
uri
# Out:
# 'spotify:track:3k79jB4aGmMDUQzEwa46Rz'

# %%
song_id = first_page['track']['album']['artists'][0]['id']
song_id
# Out:
# '1McMsnEElThX1knmY4oliG'

# %%
ext_uri = first_page['track']['album']['href']
ext_uri
# Out:
# 'https://api.spotify.com/v1/albums/5kqfR7EuGbyp8x27Pr1kY9'

# %%
artist_ID = []
song_ID = []
album_ID = []
album_name = []
artist_name = []
release_date = []
total_tracks = []
url = []
duration = []
popularity = []
exp = []
uri = []
ext_uri = []
song_time = []
song_name = []

for result in result_item:
    try:
        artist_ID.append(result['track']['id'])
    except:
        artist_ID.append('n/a')
    try:
        song_ID.append(result['track']['album']['artists'][0]['id'])
    except:
        song_ID.append('n/a')
    try:
        album_ID.append(result['track']['album']['id'])
    except:
        album_ID.append('n/a')
    try:
        album_name.append(result['track']['album']['name'])
    except:
        album_name.append('n/a')
    try:
        song_time.append(result['added_at'])
    except:
        song_time.append('n/a')
    try:
        artist_name.append(result['track']['artists'][0]['name'])
    except:
        artist_name.append('n/a')
    try:
        release_date.append(result['track']['album']['release_date'])
    except:
        release_date.append('n/a')
    try:
        total_tracks.append(result['track']['album']['total_tracks'])
    except:
        total_tracks.append('n/a')
    try:
        url.append(result['track']['album']['artists'][0]['external_urls']['spotify'])
    except:
        url.append('n/a')
    try:
        duration.append(result['track']['duration_ms'])
    except:
        duration.append('n/a')
    try:
        popularity.append(result['track']['popularity'])
    except:
        popularity.append('n/a')
    try:
        exp.append(result['track']['explicit'])
    except:
        exp.append('n/a')
    try:
        uri.append(result['track']['uri'])
    except:
        uri.append('n/a')
    try:
        ext_uri.append(result['track']['album']['href'])
    except:
        ext_uri.append('n/a')
    try:
        song_name.append(result['track']['name'])
    except:
        song_name.append('n/a')
        
    artist_element = {'Artist ID': artist_ID, 'Artiste': artist_name, 'External URL': ext_uri}
    album_element = {'Album ID': album_ID, 'Album Name': album_name, 'Release Date': release_date,
                        'Total Tracks': total_tracks, 'Track URI': uri}
    song_element = {'Song ID': song_ID, 'Total Tracks': total_tracks, 'Song Name': song_name, 'Popularity': popularity,
                       'Date Added': song_time, 'Duration': duration, 'Artist ID': artist_ID,'Album ID': album_ID}
    artist_df = pd.DataFrame(data = artist_element)
    album_df = pd.DataFrame(data = album_element)
    song_df = pd.DataFrame(data = song_element)

# %%
song_df
# Out:
#                    Song ID Total Tracks            Song Name Popularity  \
# 0   1McMsnEElThX1knmY4oliG            1              vampire         85
# 1   0nnYdIpahs41QiZ9MWp5Wx            2           Antichrist         58
# 2   5VadK1havLhK1OpKYsXv9y            1             Pakistan         64
# 3   5QrV5Vr4KdsyKtifvD6X1U            1  Bittersweet Goodbye         48
# 4   2WoVwexZuODvclzULjPQtm            1           Spirit 2.0         60
# ..                     ...          ...                  ...        ...
# 95  3OZZeMIZnTvQKjfQEEqx6C            1          Let It Rain         20
# 96  64EHXDoln95lnccszdPum0            2               JUNKIE         42
# 97  71FmTfYoEXhF3kSsbPiuKz            1          All The Way         24
# 98  3Uv5hfyuC7TkLsQ6p4ikSb            1               Modupe         43
# 99  0Dkj3iE06TJGxGIrGCmwVf            3                  idc         26
#
#               Date Added Duration               Artist ID  \
# ...

# %%
album_df
# Out:
#                   Album ID                 Album Name Release Date  \
# 0   5kqfR7EuGbyp8x27Pr1kY9                    vampire   2023-06-30
# 1   4jqlP0cYR2KLC3FDppEKC5  Antichrist / Room Service   2023-06-28
# 2   2Xjzyzg5UuBg6fGHBs1SL2                   Pakistan   2023-06-30
# 3   2n81J4HlMoEImWaC6OLeZh        Bittersweet Goodbye   2023-06-30
# 4   6idz4m2nMbiHsx3QjHhdcv                 Spirit 2.0   2023-06-28
# ..                     ...                        ...          ...
# 95  3wYiyvLGl3ft7Ln4RKWe5Z                Let It Rain   2023-06-30
# 96  4kDBAwGGcSpxs6d4FFdPYG       RAT TRAP 2: the burn   2023-06-30
# 97  3FdDfyX2JsStc0nVNSzKAY                All The Way   2023-06-30
# 98  5oKgVWWa1KtxuKGEpu2RxX                     Modupe   2023-06-28
# 99  1JfqJMtr7hhtWZ56o2Amdd                        idc   2023-06-30
#
#    Total Tracks                             Track URI
# 0             1  spotify:track:3k79jB4aGmMDUQzEwa46Rz
# ...

# %%
artist_df
# Out:
#                  Artist ID              Artiste  \
# 0   3k79jB4aGmMDUQzEwa46Rz       Olivia Rodrigo
# 1   2mvNAfnzB2gKVmLmNusrHR    Holly Humberstone
# 2   72bWarcvDzWp9aAsUWnVpq       D-Block Europe
# 3   5RHIevCuoIZcY1AlnJ01fN          Issey Cross
# 4   3JKRuo3KhL39T6XWAXPohj               Sampha
# ..                     ...                  ...
# 95  4Y2EW2u4fnOlsaAWYhHtEb    The Kingdom Choir
# 96  6azzQpelUGRtIQUfgR9R0J  Royal & the Serpent
# 97  6t4KvBSTG8J4u50RZiEob6        Saffron Stone
# 98  5lt5ftxYv3nmUOZMOzk6in               Crayon
# 99  3kx5C5gy96hofwSNdHttmu                Nxdia
#
#                                          External URL
# 0   https://api.spotify.com/v1/albums/5kqfR7EuGbyp...
# 1   https://api.spotify.com/v1/albums/4jqlP0cYR2KL...
# 2   https://api.spotify.com/v1/albums/2Xjzyzg5UuBg...
# 3   https://api.spotify.com/v1/albums/2n81J4HlMoEI...
# 4   https://api.spotify.com/v1/albums/6idz4m2nMbiH...
# ..                                                ...
# ...

# %%
song_df = song_df.drop_duplicates()
album_df = album_df.drop_duplicates()
artist_df = artist_df.drop_duplicates()

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Song ID       100 non-null    object
#  1   Total Tracks  100 non-null    object
#  2   Song Name     100 non-null    object
#  3   Popularity    100 non-null    object
#  4   Date Added    100 non-null    object
#  5   Duration      100 non-null    object
#  6   Artist ID     100 non-null    object
#  7   Album ID      100 non-null    object
# dtypes: object(8)
# memory usage: 7.0+ KB

# %%
song_df['Date Added'] = pd.to_datetime(song_df['Date Added'])

# %%
song_df
# Out:
#                    Song ID Total Tracks            Song Name Popularity  \
# 0   1McMsnEElThX1knmY4oliG            1              vampire         85
# 1   0nnYdIpahs41QiZ9MWp5Wx            2           Antichrist         58
# 2   5VadK1havLhK1OpKYsXv9y            1             Pakistan         64
# 3   5QrV5Vr4KdsyKtifvD6X1U            1  Bittersweet Goodbye         48
# 4   2WoVwexZuODvclzULjPQtm            1           Spirit 2.0         60
# ..                     ...          ...                  ...        ...
# 95  3OZZeMIZnTvQKjfQEEqx6C            1          Let It Rain         20
# 96  64EHXDoln95lnccszdPum0            2               JUNKIE         42
# 97  71FmTfYoEXhF3kSsbPiuKz            1          All The Way         24
# 98  3Uv5hfyuC7TkLsQ6p4ikSb            1               Modupe         43
# 99  0Dkj3iE06TJGxGIrGCmwVf            3                  idc         26
#
#                   Date Added Duration               Artist ID  \
# ...
